# %%
import pandas as pd

read_file = pd.read_csv (r'C:\Users\MKNDEA002\Desktop\Ultrasound\refined2\multimetersmall.txt')
read_file.to_csv (r'C:\Users\MKNDEA002\Desktop\Ultrasound\refined2\multimetersmall.csv', index=None)

# %%
import matplotlib.pyplot as plt
import numpy as np

dataArray = np.genfromtxt('pineapple1.csv', delimiter=',', names=True)

plt.figure()
for col_name in dataArray.dtype.names:
    plt.plot(dataArray[col_name], label=col_name)
plt.legend()
plt.show()

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

im = Image.open("test.ppm")
im.save("test.jpg")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-18-39f0ae3f32e7> in <module>
#       1 from PIL import Image
#       2
# ----> 3 im = Image.open("test.ppm")
#       4 im.save("test.jpg")
#
# ~\.julia\conda\3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2965     for message in accept_warnings:
#    2966         warnings.warn(message)
# -> 2967     raise UnidentifiedImageError(
#    2968         "cannot identify image file %r" % (filename if filename else fp)
#    2969     )
#
# UnidentifiedImageError: cannot identify image file 'test.ppm'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_csv('Wood1_FFT.txt',index_col=0)
data = data['Torque'].astype(float).values
print(data)

N = data.shape[0] #number of elements
t = np.linspace(0, 300, N) 
#t=np.arange(N)
s = data

fft = np.fft.fft(s)
fftfreq = np.fft.fftfreq(len(s))

T = t[1] - t[0]
print(T)

f = np.linspace(0, 1 / T, N)
plt.ylabel("Amplitude")
plt.xlabel("Frequency [kHz, 0 = centre frequency of 40kHz]")
plt.plot(fftfreq, np.absolute(fft))
#plt.xlim(0,100)
# Out:
# [2095. 2090. 2092. ... 2163. 2159. 2148.]
# 0.050008334722453744

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
data = pd.read_csv('pineapple1_FFT.txt',index_col=0)
data = data['Torque'].astype(float).values
print(data)

N = data.shape[0] #number of elements
t = np.linspace(0, 300, N) 
#t=np.arange(N)
s = data

fft = np.fft.fft(s)
fftfreq = np.fft.fftfreq(len(s))

T = t[1] - t[0]
print(T)

f = np.linspace(0, 1 / T, N)
plt.ylabel("Amplitude")
plt.xlabel("Frequency [kHz, 0 = centre frequency of 40kHz]")
plt.plot(fftfreq, np.absolute(fft))
#plt.xlim(0,100)
# Out:
# [2101. 2095. 2100. ... 2111. 2108. 2106.]
# 0.050008334722453744

# %%
import numpy as np
import scipy as sy
import scipy.fftpack as syfp
import pylab as pyl

# Read in data from file here
array = np.loadtxt("orange1.csv")
length = len(array)
# Create time data for x axis based on array length
x = sy.linspace(0.00001, length*0.00001, num=length)

# Do FFT analysis of array
FFT = sy.fft(array)
# Getting the related frequencies
freqs = syfp.fftfreq(array.size, d=(x[1]-x[0]))

# Create subplot windows and show plot
pyl.subplot(211)
pyl.plot(x, array)
pyl.subplot(212)
pyl.plot(freqs, sy.log10(FFT), 'x')
pyl.show()
# Out:
# <ipython-input-20-af8836a381be>:10: DeprecationWarning: scipy.linspace is deprecated and will be removed in SciPy 2.0.0, use numpy.linspace instead
#   x = sy.linspace(0.00001, length*0.00001, num=length)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-af8836a381be> in <module>
#      11
#      12 # Do FFT analysis of array
# ---> 13 FFT = sy.fft(array)
#      14 # Getting the related frequencies
#      15 freqs = syfp.fftfreq(array.size, d=(x[1]-x[0]))
#
# TypeError: 'module' object is not callable

# %%
pip install scipy
# Out:
#   File "<ipython-input-16-8cf8c2fb165f>", line 1
#     pip install scipy
#         ^
# SyntaxError: invalid syntax
